# %%
source('Variables.r')
source('Timedeppar.r')
source('Visualization.r')
# Out:
# Installing package into ‘/home/alberto/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/home/alberto/R/x86_64-pc-linux-gnu-library/3.6’
# (as ‘lib’ is unspecified)

# %%
inf <- inference('Series2')
# Out:
# infer.timedeppar (timedeppar 1.0.2 2022-05-24): starting new Markov Chain
#
#   number of constant parameters:          3
#
#   number of time-dependent parameters:    1
#
#   number of estimated process parameters: 3
#
# Warning message in infer.timedeppar(loglikeli = loglikeli, param.ini = param_init, :
# “log prior of process parameters = -Inf at xi_mean=1.01622, xi_sd=0.0977042, xi_gamma=0.00492022
# ”
# Warning message in infer.timedeppar(loglikeli = loglikeli, param.ini = param_init, :
# “log prior of process parameters = -Inf at xi_mean=1.00159, xi_sd=0.094409, xi_gamma=0.00491211
# ”
# Warning message in infer.timedeppar(loglikeli = loglikeli, param.ini = param_init, :
# “log prior of process parameters = -Inf at xi_mean=1.00159, xi_sd=0.0918246, xi_gamma=0.0047263
# ”
# Warning message in infer.timedeppar(loglikeli = loglikeli, param.ini = param_init, :
# “log prior of process parameters = -Inf at xi_mean=1.00427, xi_sd=0.0975168, xi_gamma=0.00499425
# ”
# ...

# %%
df<-inf$df

plot_diff(df)
# Out:
# Plot with title “Time difference”
# NULL
# Plot with title “Xi_inf”
